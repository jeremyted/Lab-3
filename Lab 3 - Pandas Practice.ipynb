# %% [markdown]
# # Lab 3

# %% [markdown]
# Mauricio Garcia 11/14/2019

# %% [markdown]
# ### Abstract

# %% [markdown]
# In this lab, I mess around with a crime stats dataset and perform some mathematical calculations on it. The purpose of this lab overall was to see what crime data would look like from a couple different perspectives as they span over time. The data collection was based in Seattle.

# %% [markdown]
# ### Dataset preparation

# %% [markdown]
# I import all the modules I need for this lab below.

# %%
# Here are some modules
import pandas as pd
import numpy as np
import statistics
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data modeling

# %%
# And I will open up my file here
df = pd.read_csv('crimenes.csv')
# Here, I show the first couple rows
df.head(5)
# Out:
#    Report_Year  Census_Tract_1990               Crime_Type  Report_Year_Total
# 0         1996                1.0       Aggravated Assault                 11
# 1         1996                1.0                 Homicide                  0
# 2         1996                1.0  NonResidential Burglary                 41
# 3         1996                1.0    Property Crimes Total                430
# 4         1996                1.0                     Rape                  2

# %%
# The dataset looks pretty clean so I can go ahead and open up more of the file. I want to now look at the end of this dataset.
df.tail(5)
# Out:
#        Report_Year  Census_Tract_1990            Crime_Type  Report_Year_Total
# 14263         2007               99.0                  Rape                  4
# 14264         2007               99.0  Residential Burglary                 36
# 14265         2007               99.0               Robbery                  3
# 14266         2007               99.0                 Theft                147
# 14267         2007               99.0         Vehicle Theft                 52

# %%
# I think it's important to also take a look at general info on this dataset, so here's just that
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14268 entries, 0 to 14267
# Data columns (total 4 columns):
# Report_Year          14268 non-null int64
# Census_Tract_1990    14236 non-null float64
# Crime_Type           14268 non-null object
# Report_Year_Total    14268 non-null int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 446.0+ KB

# %% [markdown]
# As you can see, there are a total of 14,268 entries. Now, I am ready to analyze this data.

# %% [markdown]
# ### Data analysis

# %% [markdown]
# Here, I will perform a series of mathematical calculations to gather more information from the data that may not stick out as much from simply glancing at the data.

# %%
# I want to find the mean of my columns, so for that, I'll use this code
df.mean()
# Out:
# Report_Year          2001.327586
# Census_Tract_1990      60.955128
# Report_Year_Total      75.137090
# dtype: float64

# %% [markdown]
# Out of the things here, one of the rows of information is actually usable. The average of the report years and the census tract doesn't really matter much to me, but I find it most interesting to see how many crimes would be logged on average every year

# %%
# now let's organize the dataset differently and look at the criminal cases 
df.sort_values("Crime_Type")
# Out:
#        Report_Year  Census_Tract_1990            Crime_Type  Report_Year_Total
# 0             1996               1.00    Aggravated Assault                 11
# 1350          1997              11.00    Aggravated Assault                  4
# 8070          2002              52.00    Aggravated Assault                 26
# 8060          2002              51.00    Aggravated Assault                  7
# 11790         2005              54.00    Aggravated Assault                 12
# 3480          1998              80.00    Aggravated Assault                103
# 8050          2002              50.00    Aggravated Assault                  0
# 1340          1997             109.00    Aggravated Assault                 35
# 11800         2005              55.00    Aggravated Assault                  1
# 8040          2002               5.00    Aggravated Assault                  1
# 3490          1998              81.00    Aggravated Assault                215
# ...

# %% [markdown]
# ### Conclusions

# %% [markdown]
# From looking at the data, I have reached the conclusion that there a lot of crimes that happen in Seattle. It was surprising to also see the average amount of crimes comitted every year.

# %% [markdown]
# ### Acknowledgments

# %% [markdown]
# I want to thank Ms. Sconyers for helping me on some of the code here.
